# %%
import numpy as np
import pandas as pd
import matplotlib 
from matplotlib import pyplot as plt

# %%
fifa = pd.read_csv('players_20.csv')
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, CF, ST
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 3          E. Hazard                          Eden Hazard           LW, CF
# 4       K. De Bruyne                      Kevin De Bruyne          CAM, CM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
fifa.shape
# Out:
# (18483, 110)

# %%
fifa.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   18483.000000  18483.000000  18483.000000  1.823300e+04   18243.000000
# mean   219768.374885     66.198885     71.500893  2.495171e+06    9745.598312
# std     28047.535516      6.950927      6.140787  5.587820e+06   21448.995068
# min        41.000000     48.000000     49.000000  8.000000e+03     500.000000
# 25%    204495.500000     62.000000     67.000000  3.250000e+05    1000.000000
# 50%    226215.000000     66.000000     71.000000  7.250000e+05    3000.000000
# 75%    240880.000000     71.000000     75.000000  2.100000e+06    9000.000000
# max    252905.000000     94.000000     95.000000  1.055000e+08  560000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  18483.000000  18483.000000  18483.000000   18243.000000  17858.000000
# mean      25.283071    181.348212     75.259049   45222.312723      1.400997
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# player_positions
# overall
# potential
# value_eur
# wage_eur
# age
# dob
# height_cm
# weight_kg
# club_team_id
# club_name
# league_name
# league_level
# club_position
# club_jersey_number
# club_loaned_from
# club_joined
# club_contract_valid_until
# nationality_id
# nationality_name
# nation_team_id
# nation_position
# nation_jersey_number
# preferred_foot
# weak_foot
# skill_moves
# international_reputation
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# player_traits
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
fifa['nationality_name'].value_counts()[0:5]
# Out:
# England      1670
# Germany      1218
# Spain        1045
# France       1004
# Argentina     886
# Name: nationality_name, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize = [9,6])
plt.bar(list(fifa['nationality_name'].value_counts()[0:5].keys()),(fifa['nationality_name'].value_counts()[0:5]), color=['r','g','b'])
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi  560000.0
# 1  Cristiano Ronaldo  410000.0
# 2          Neymar Jr  290000.0
# 3          E. Hazard  470000.0
# 4       K. De Bruyne  370000.0

# %%
player_salary = player_salary.sort_values(by=['wage_eur'],ascending=False)
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi  560000.0
# 3           E. Hazard  470000.0
# 1   Cristiano Ronaldo  410000.0
# 17       A. Griezmann  370000.0
# 4        K. De Bruyne  370000.0

# %%
plt.figure(figsize = [9,6])
plt.bar(list(player_salary['short_name'][0:5]),list(player_salary['wage_eur'][0:5]), color=['r','g','b'])
plt.show()

# %%
fifa['nationality_name'] == 'Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18478    False
# 18479    False
# 18480    False
# 18481    False
# 18482    False
# Name: nationality_name, Length: 18483, dtype: bool

# %%
germany =  fifa[fifa['nationality_name'] == 'Germany']
germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 7      192448  https://sofifa.com/player/192448/marc-andre-te...
# 25     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 30     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 31     188350  https://sofifa.com/player/188350/marco-reus/20...
# 45     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name player_positions  overall  potential  \
# 7   M. ter Stegen  Marc-André ter Stegen               GK       90         93
# 25       M. Neuer     Manuel Peter Neuer               GK       88         88
# 30       T. Kroos             Toni Kroos               CM       88         88
# 31        M. Reus             Marco Reus      CAM, LM, ST       88         88
# 45     M. Hummels           Mats Hummels               CB       87         87
#
#      value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
germany.sort_values(by=['height_cm'], ascending = False).iloc[0:5,0:21]
# Out:
#        sofifa_id                                         player_url  \
# 8550      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1094      200212  https://sofifa.com/player/200212/michael-esser...
# 1411      199833  https://sofifa.com/player/199833/lars-unnersta...
# 16208     240218  https://sofifa.com/player/240218/alexander-wei...
# 13736     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#           short_name            long_name player_positions  overall  \
# 8550       A. Seydel         Aaron Seydel           ST, LM       67
# 1094        M. Esser        Michael Esser               GK       77
# 1411   L. Unnerstall      Lars Unnerstall               GK       76
# 16208   A. Weidinger  Alexander Weidinger               GK       58
# 13736   L. Watkowiak      Lukas Watkowiak               GK       62
#
#        potential  value_eur  wage_eur  age  ... height_cm  weight_kg  \
# 8550          73  1100000.0    9000.0   23  ...       199         90
# ...

# %%
germany.sort_values(by=['weight_kg'], ascending = False).iloc[0:5,0:21]
# Out:
#        sofifa_id                                         player_url  \
# 1411      199833  https://sofifa.com/player/199833/lars-unnersta...
# 13736     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 443       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1094      200212  https://sofifa.com/player/200212/michael-esser...
# 13775     241388  https://sofifa.com/player/241388/dennis-smarsc...
#
#           short_name                long_name player_positions  overall  \
# 1411   L. Unnerstall          Lars Unnerstall               GK       76
# 13736   L. Watkowiak          Lukas Watkowiak               GK       62
# 443      R. Fährmann  Ralf Sebastian Fährmann               GK       80
# 1094        M. Esser            Michael Esser               GK       77
# 13775     D. Smarsch           Dennis Smarsch               GK       62
#
#        potential   value_eur  wage_eur  age  ... height_cm  weight_kg  \
# ...

# %%
germany.sort_values(by=['wage_eur'], ascending = False).iloc[0:5,0:21]
# Out:
#      sofifa_id                                         player_url  \
# 30      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 7       192448  https://sofifa.com/player/192448/marc-andre-te...
# 71      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 126     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 31      188350  https://sofifa.com/player/188350/marco-reus/20...
#
#         short_name              long_name player_positions  overall  \
# 30        T. Kroos             Toni Kroos               CM       88
# 7    M. ter Stegen  Marc-André ter Stegen               GK       90
# 71         L. Sané        Leroy Aziz Sané               LW       86
# 126    İ. Gündoğan         İlkay Gündoğan          CM, CDM       84
# 31         M. Reus             Marco Reus      CAM, LM, ST       88
#
#      potential   value_eur  wage_eur  age  ... height_cm  weight_kg  \
# 30          88  57000000.0  330000.0   29  ...       183         76
# ...

# %%
germany[['short_name','wage_eur']].sort_values(by=['wage_eur'], ascending = False).head()
# Out:
#         short_name  wage_eur
# 30        T. Kroos  330000.0
# 7    M. ter Stegen  250000.0
# 71         L. Sané  195000.0
# 126    İ. Gündoğan  180000.0
# 31         M. Reus  165000.0

# %%
#shooting

# %%
player_shooting = fifa[['short_name','shooting']]

# %%
player_shooting.sort_values(by=['shooting'], ascending=False).head()
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 0            L. Messi      92.0
# 19            H. Kane      91.0
# 11          S. Agüero      90.0
# 13          L. Suárez      89.0

# %%
#defending

# %%
player_defending = fifa[['short_name','defending']]

# %%
player_defending.sort_values(by=['defending'], ascending=False).head()
# Out:
#       short_name  defending
# 10  G. Chiellini       90.0
# 8    V. van Dijk       90.0
# 29      D. Godín       89.0
# 45    M. Hummels       89.0
# 18  K. Koulibaly       89.0

# %%
real_madrid = fifa[fifa['club_name'] == 'Real Madrid CF']

# %%
real_madrid.sort_values(by=['wage_eur'],ascending = False).head()
# Out:
#     sofifa_id                                         player_url  \
# 3      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 6      177003  https://sofifa.com/player/177003/luka-modric/2...
# 30     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 12     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name player_positions  overall  potential  \
# 3      E. Hazard          Eden Hazard           LW, CF       91         91
# 6      L. Modrić          Luka Modrić               CM       90         90
# 30      T. Kroos           Toni Kroos               CM       88         88
# 12  Sergio Ramos  Sergio Ramos García               CB       89         89
# 42    K. Benzema        Karim Benzema           CF, ST       87         87
#
#      value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
real_madrid.sort_values(by=['defending'], ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 12      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 93      201535  https://sofifa.com/player/201535/raphael-varan...
# 52      200145  https://sofifa.com/player/200145/carlos-henriq...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 407     240130  https://sofifa.com/player/240130/eder-gabriel-...
#
#        short_name                          long_name player_positions  \
# 12   Sergio Ramos                Sergio Ramos García               CB
# 93      R. Varane                     Raphaël Varane               CB
# 52       Casemiro  Carlos Henrique Venancio Casimiro              CDM
# 94       Carvajal              Daniel Carvajal Ramos               RB
# 407  Éder Militão               Éder Gabriel Militão           CB, RB
#
#      overall  potential   value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
real_madrid.sort_values(by=['shooting'], ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 77      173731  https://sofifa.com/player/173731/gareth-bale/2...
# 89      198710  https://sofifa.com/player/198710/james-rodrigu...
# 3       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 42      165153  https://sofifa.com/player/165153/karim-benzema...
# 237     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name player_positions  overall  \
# 77        G. Bale            Gareth Frank Bale       RW, LW, ST       85
# 89   J. Rodríguez  James David Rodríguez Rubio      CAM, CM, RM       85
# 3       E. Hazard                  Eden Hazard           LW, CF       91
# 42     K. Benzema                Karim Benzema           CF, ST       87
# 237      L. Jović                   Luka Jović               ST       83
#
#      potential   value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
real_madrid['nationality_name'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality_name, dtype: int64
